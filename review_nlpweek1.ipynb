# %%
# !pip install nltk

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
#코퍼스길이
len(text1)
# Out:
# 260819

# %%
#unique sets
len(set(text1))
# Out:
# 19317

# %%
#오름차순 정렬
len(sorted(set(text1)))
# Out:
# 19317

# %%
#lexical richiness
len(set(text1))/len(text1)
# Out:
# 0.07406285585022564

# %%
#특정 단어 개수 세기
text1.count("whale")
# Out:
# 906

# %%
text3.count("whale")
# Out:
# 0

# %%
#lexical richness of txt2
len(set(text2))/len(text2)
# Out:
# 0.04826383002768831

# %%
#전체 텍스트에서 이단어가 몇퍼센트인지
text1.count("whale")/len(text1)*100
# Out:
# 0.3473673313677301

# %%
#txt5 에서 'lol'이 차지하는 비율
text5.count("lol")/len(text5)*100
# Out:
# 1.5640968673628082

# %%
#function
def percentage(count, total):
    return 100*count/total

# %%
#lexical_richness(text)함수 만들기
def lexical_richness(text):
    return len(set(text))/len(text)

# %%
lexical_richness(text1)
# Out:
# 0.07406285585022564

# %%
#for loop
#전체 텍스트에 대해서 lexical_richness
texts=[text1, text2, text3, text4, text5, text6, text7, text8, text9]

# %%
for s in texts:
    print (s, lexical_richness(s))
# Out:
# <Text: Moby Dick by Herman Melville 1851> 0.07406285585022564
# <Text: Sense and Sensibility by Jane Austen 1811> 0.04826383002768831
# <Text: The Book of Genesis> 0.06230453042623537
# <Text: Inaugural Address Corpus> 0.06617622515804722
# <Text: Chat Corpus> 0.13477005109975562
# <Text: Monty Python and the Holy Grail> 0.1276595744680851
# <Text: Wall Street Journal> 0.12324685128531129
# <Text: Personals Corpus> 0.22765564002465585
# <Text: The Man Who Was Thursday by G . K . Chesterton 1908> 0.0983485761345412

# %%
#list
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
sent1.append("please")

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.', 'please']

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.index("whale") #맨처음 웨일이 나온겨
# Out:
# 108

# %%
#내장함수 : concordance, similar, common_texts, dispersion_plot
text1.concordance("whale")
# Out:
# Displaying 25 of 1226 matches:
# s , and to teach them by what name a whale - fish is to be called in our tongue
# t which is not true ." -- HACKLUYT " WHALE . ... Sw . and Dan . HVAL . This ani
# ulted ." -- WEBSTER ' S DICTIONARY " WHALE . ... It is more immediately from th
# ISH . WAL , DUTCH . HWAL , SWEDISH . WHALE , ICELANDIC . WHALE , ENGLISH . BALE
# HWAL , SWEDISH . WHALE , ICELANDIC . WHALE , ENGLISH . BALEINE , FRENCH . BALLE
# least , take the higgledy - piggledy whale statements , however authentic , in
#  dreadful gulf of this monster ' s ( whale ' s ) mouth , are immediately lost a
#  patient Job ." -- RABELAIS . " This whale ' s liver was two cartloads ." -- ST
#  Touching that monstrous bulk of the whale or ork we have received nothing cert
#  of oil will be extracted out of one whale ." -- IBID . " HISTORY OF LIFE AND D
# ise ." -- KING HENRY . " Very like a whale ." -- HAMLET . " Which to secure , n
# ...

# %%
text1.similar("whale")
# Out:
# ship boat sea time captain world man deck pequod other whales air
# water head crew line thing side way body

# %%
text1.common_contexts(["whale", "ship"]) #list
# Out:
# the_s the_and the_is the_in the_the the_as the_was the_which the_i
# a_in the_has the_when the_had the_with the_to the_by the_so the_that
# the_would the_a

# %%
text1.dispersion_plot(["whale", "ship"])

# %%
#freq distribution
fdist1 = FreqDist(text1)

# %%
fdist1
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
fdist1.most_common(5) #제일 많은 단어 5개
# Out:
# [(',', 18713), ('the', 13721), ('.', 6862), ('of', 6536), ('and', 6024)]

# %%
fdist1["whale"]
# Out:
# 906

# %%
text1.count("whale")
# Out:
# 906

# %%
fdist1.plot(50)

# %%
fdist1.plot(50, cumulative=True)

# %%
#hapax; 한번만 등장하는 단어
fdist1.hapaxes()
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %%
len(fdist1.hapaxes())
# Out:
# 9002

# %%
#전체 텍스트에서 단어의 길이만 출력
#[i am a girl.] =>[1,2,1,4]
#lambda: [x for x in list]
[len(w) for w in text1]
#[] 없이 하니까 invalid syntax
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
[w for w in text1]
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'Supplied',
#  'by',
#  'a',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'to',
#  'a',
#  'Grammar',
#  'School',
#  ')',
#  'The',
#  'pale',
#  'Usher',
#  '--',
#  'threadbare',
#  'in',
#  'coat',
#  ',',
#  'heart',
#  ',',
#  'body',
#  ',',
#  'and',
#  'brain',
#  ';',
#  'I',
#  'see',
#  'him',
#  'now',
#  '.',
#  'He',
#  'was',
#  'ever',
#  'dusting',
#  'his',
#  'old',
#  'lexicons',
#  'and',
#  'grammars',
#  ',',
#  'with',
#  'a',
#  'queer',
#  'handkerchief',
#  ',',
#  'mockingly',
#  'embellished',
#  'with',
#  'all',
#  'the',
#  'gay',
#  'flags',
#  'of',
#  'all',
#  'the',
#  'known',
#  'nations',
#  'of',
#  'the',
#  'world',
#  '.',
#  'He',
#  'loved',
#  'to',
#  'dust',
#  'his',
#  'old',
#  'grammars',
#  ';',
#  'it',
#  'somehow',
#  'mildly',
#  'reminded',
#  'him',
#  'of',
#  'his',
#  'mortality',
#  '.',
#  '"',
# ...

# %%
#조건:len>10
[len(w) for w in text1 if len(w)>10]
# Out:
# [11,
#  12,
#  11,
#  13,
#  11,
#  11,
#  11,
#  12,
#  13,
#  11,
#  11,
#  14,
#  13,
#  11,
#  11,
#  12,
#  11,
#  12,
#  11,
#  16,
#  11,
#  11,
#  13,
#  12,
#  11,
#  13,
#  11,
#  11,
#  13,
#  12,
#  13,
#  11,
#  13,
#  11,
#  11,
#  11,
#  12,
#  11,
#  11,
#  11,
#  11,
#  15,
#  11,
#  11,
#  11,
#  13,
#  12,
#  12,
#  13,
#  14,
#  12,
#  11,
#  11,
#  11,
#  11,
#  11,
#  12,
#  12,
#  11,
#  13,
#  12,
#  13,
#  11,
#  12,
#  11,
#  11,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  13,
#  11,
#  11,
#  12,
#  13,
#  12,
#  12,
#  11,
#  13,
#  14,
#  12,
#  13,
#  11,
#  11,
#  11,
#  12,
#  12,
#  11,
#  12,
#  11,
#  11,
#  11,
#  11,
#  13,
#  12,
#  11,
#  11,
#  12,
#  11,
#  12,
#  11,
#  11,
#  14,
#  11,
#  11,
#  13,
#  13,
#  13,
#  11,
#  13,
#  12,
#  13,
#  11,
#  11,
#  11,
#  11,
#  11,
#  12,
#  12,
#  13,
#  11,
#  12,
#  12,
#  12,
#  11,
#  14,
#  11,
#  13,
#  12,
#  11,
#  14,
#  12,
#  12,
#  12,
#  12,
#  14,
#  13,
#  13,
#  12,
#  11,
# ...

# %%
#그런 조건을 채우는 단어가 뭔지 알고싶으면 앞에만 바꾸면 돼
[w for w in text1 if len(w)>10]
# Out:
# ['Consumptive',
#  'handkerchief',
#  'embellished',
#  'signification',
#  'immediately',
#  'ERROMANGOAN',
#  'painstaking',
#  'entertaining',
#  'promiscuously',
#  'generations',
#  'commentator',
#  'unsplinterable',
#  'incontinently',
#  'Whirlpooles',
#  'immediately',
#  'sovereignest',
#  'spermacetti',
#  'Commonwealth',
#  'SPITZBERGEN',
#  'CIRCUMNAVIGATION',
#  'harpooneers',
#  'Spitzbergen',
#  'insupportable',
#  'contemptible',
#  'Spermacetti',
#  'consideration',
#  'mammiferous',
#  'Spermacetti',
#  'CONVERSATIONS',
#  'astonishment',
#  'consideration',
#  'interesting',
#  'opportunities',
#  'disposition',
#  'offensively',
#  'mischievous',
#  'transactions',
#  'persevering',
#  'APPLICATION',
#  'UNPUBLISHED',
#  'Pedestrians',
#  'perpendicularly',
#  'threatening',
#  'destruction',
#  'circulation',
#  'involuntarily',
#  'deliberately',
#  'methodically',
#  'philosophical',
#  'Circumambulate',
#  'metaphysical',
#  'overlapping',
#  'ungraspable',
# ...

# %%
#
sorted(len(w) for w in text1 if len(w)>10)
# Out:
# [11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
# ...
